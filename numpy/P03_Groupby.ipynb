# %%
# GroupBy分组后的对象
import pandas as pd
df = pd.read_csv("E:\\大模型课程\\05_尚硅谷大模型技术之Numpy&Pandas\\2.资料\\data\\employees.csv")
# dept_group = df.groupby("department_id")
# dept_group.get_group(50)
# dept_group["salary"]
# dept_group["salary"].mean()
#
# for dept_id,group in dept_group:
#     print(f"当前组为{dept_id}，组里的数据情况{group.shape}:")
#     print(group.iloc[:,0:3])
#     print("-------------------")

salary_mean = df.groupby(["department_id","job_id"],as_index=False)[
    ["salary", "commission_pct"]
].mean()
# salary_mean
# salary_mean.reset_index(inplace=True)
salary_mean.index
# salary_mean.columns
# salary_mean.values
# Out:
# RangeIndex(start=0, stop=19, step=1)

# %%
df = pd.read_csv("E:\\大模型课程\\05_尚硅谷大模型技术之Numpy&Pandas\\2.资料\\data\\employees.csv")
type(df.iloc[9:16]["salary"])

# df1 = df.iloc[9:16][["first_name","salary"]]
# df1["cut_res"] = pd.cut(df.iloc[9:16]["salary"],3)
# pd.cut(df.iloc[9:16]["salary"],3)

# df1
pd.cut(df.iloc[9:16]["salary"],[0,10000,20000])

s = pd.Series([1,0,3])
s == 0
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool
