# %% [markdown]
# # 缺失值处理函数

# %%
import numpy as np
import pandas as pd
s = pd.Series([np.nan, None, pd.NA])
# s.isna()
# s.isnull()
# s.notna()
# s.notnull()

# %%
# 加载包含缺失值的数据

# df = pd.read_csv("E:\\大模型课程\\05_尚硅谷大模型技术之Numpy&Pandas\\2.资料\\data\\weather_withna.csv")
# df = pd.read_csv("E:\\大模型课程\\05_尚硅谷大模型技术之Numpy&Pandas\\2.资料\\data\\weather_withna.csv",keep_default_na=True)

import missingno as msno
# 通过na_values参数将指定值设置为缺失值
df = pd.read_csv("E:\\大模型课程\\05_尚硅谷大模型技术之Numpy&Pandas\\2.资料\\data\\weather_withna.csv",na_values=["2015-12-31"])

# df.tail()
# df.isnull().sum()
# msno.bar(df)
msno.heatmap(df)

# %%
# Series中剔除缺失值
s = pd.Series([1, pd.NA, None])
s.dropna()
# DataFrame中剔除缺失值
df = pd.DataFrame([[1, pd.NA, 2], [2, 3, 5], [pd.NA, 4, 6]])
# df.dropna()
# df.dropna(axis=1)
df = pd.DataFrame([[1, pd.NA, 2], [pd.NA, pd.NA, 5], [pd.NA, pd.NA, pd.NA]])
# df.dropna(axis=0, how='all')
# 如果至少有2个值不是缺失值,则保留这一行
df.dropna(axis=0, thresh=2)
# Out:
#    0     1  2
# 0  1  <NA>  2

# %%
# 使用固定值填充缺失值
df = pd.read_csv("E:\\大模型课程\\05_尚硅谷大模型技术之Numpy&Pandas\\2.资料\\data\\weather_withna.csv")

# 传入固定值参数
# df.fillna(0, inplace=True)
# 传入字典参数
# df.fillna({"temp_max":30,"temp_min":2}, inplace=True)

# 使用平均值进行填充
# df.fillna(df[["precipitation", "temp_max", "temp_min", "wind"]].mean(), inplace=True)

# 使用前后有效值进行填充
# df.ffill(inplace=True)
# df.bfill(inplace=True)
# df.tail()

# 线性填充
s = pd.Series([1, np.nan, 3, 4, np.nan, 6])

s.interpolate(inplace=True)

s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    6.0
# dtype: float64
